# %%
#update compared to trial 1: target values uniformly distributed every trial again!

import copy
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt
import time
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

import keras
from keras import initializers
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from keras.constraints import max_norm
from scipy.stats import pearsonr
from scipy.stats import expon

from time import time
import math

import random
from scipy.misc import comb
# Out:
# Using TensorFlow backend.

# %%
### TUNING PARAMETERS ###

observations = 599                    # Sample construction
X_val_size = 99
n_split = 5
                      
N_nodes = [1, 2, 3]                    # Design MLP                       
t=0
H_layers = [1, 2, 3, 5, 10]


m = 0                                  # Distribution parameters
sd = 1               
alpha = 0.5
beta = 0.5
lambd = 1.5
a = 0.25
b = 0.75

                                       # Grid search hyperparameters
batch_size = [10, 25, 50, 100]
epochs = [50, 100, 500]

dropout_rate = [i/5 for i in range(0,5)]
learn_rate = [0.001, 0.01, 0.1, 0.2, 0.3]
weight_constraint = [0, 3, 5]

neurons = [1, 2, 3, 4, 5, 10, 20, 30]

                                       #grid_search or random_search?
search = "random_search"
n_iter_search = 10

t_size = 0.4

# %%
### FUNCTIONS ###

def create_dataset():
    x = np.array([[random.expovariate(lambd) for i in range(N_nodes[t])] for i in range(0, observations+1)])
    #y = np.array([0.95*i/observations+0.05 for i in range(0,observations+1)])
    
    #check dimensionality
    print('dimensionality of x :', np.shape(x))
    #print('dimensionality of y: ', np.shape(y))
    
    #sort
    x_sorted = np.sort(x,0)

    #correlation
    #for i in range(N_nodes[t]):
    #    print("correlation for " +str(N_nodes[t])+ ": ",pearsonr(x_sorted[:,0], y))
    
    print('\n')
    #return (x_sorted, y)
    return x_sorted

def create_targetset():
    #x = np.array([[random.expovariate(lambd) for i in range(N_nodes[t])] for i in range(0, observations+1)])
    #y = np.array([0.95*i/observations+0.05 for i in range(0,observations+1)])
    y = np.sort(np.array([random.uniform(0,1) for i in range(0,observations+1)]))
    
    #check dimensionality
    #print('dimensionality of x :', np.shape(x))
    print('dimensionality of y: ', np.shape(y))
    
    #sort
    #x_sorted = np.sort(x,0)

    #correlation
    #for i in range(N_nodes[t]):
    #    print("correlation for " +str(N_nodes[t])+ ": ",pearsonr(x_sorted[:,0], y))
    
    print('\n')
    #return (x_sorted, y)
    return y

def scale(x):
    ### scale ###
    mean = np.mean(x, axis=0)
    var = np.var(x, axis=0)
    print("mean is: ", mean)
    print("variance is: ", var)

    x_scaled = np.array([(i-mean)/np.sqrt(var) for i in x])
    
    print('\n')
    return x_scaled


def plot_dataset(x, y):
    
    for i in range(N_nodes[t]):
        plt.scatter(x[:,i], y, c=y)
        plt.ylabel('Cumulative Probability < RV value')
        plt.xlabel('Random Variable (RV) value')
        plt.plot(x[:,i], expon.cdf(x[:,i], scale=1/lambd), label="actual CDF")
        plt.colorbar(ticks=np.linspace(min(y), max(y), 10, endpoint=True))
        plt.show()
    

def plot_cdf(X_train, Y_train, X_test, Y_test, X_train_scaled, X_test_scaled, predictions):
        for i in range(N_nodes[t]):
            plt.scatter(X_test[:,i], Y_test, label='test set')
            plt.scatter(X_test[:,i], predictions, label='fitted set')
            plt.scatter(X_test[:,i], expon.cdf(X_test[:,i],scale=1/lambd), label="actual CDF")

            plt.ylabel('Cumulative Probability < RV value')
            plt.xlabel('Random Variable (RV) value')
            plt.legend()
            plt.show()
        
def create_model(H_layers=1, optimizer='Adam', init=initializers.RandomNormal(mean=0, stddev=0.25, seed=None), activation='sigmoid', dropout_rate=0.0, learn_rate=0.01, neurons=1, weight_constraint=0):
#def create_model(optimizer, init, dropout_rate, learn_rate, activation, neurons, weight_constraint):
    ### CREATE MODEL ###
    MLP = Sequential()
    #MLP.add(Dropout(dropout_rate, input_shape=(N_nodes[t],)))
    MLP.add(Dense(neurons, input_dim=N_nodes[t], kernel_initializer=init, activation=activation, kernel_constraint=max_norm(weight_constraint)))    #hidden layer
    #MLP.add(Dropout(dropout_rate))
    for h in range(1,H_layers):                                                                     #multiple hidden layers
        MLP.add(Dense(neurons, kernel_initializer=init, activation=activation, kernel_constraint=max_norm(weight_constraint)))
        #MLP.add(Dropout(dropout_rate))
    MLP.add(Dense(1, kernel_initializer=init, activation='sigmoid'))                                 #output layer
    MLP.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
    
    return MLP

def train_ANN(search, X_train, Y_train, X_test):
    
    model = keras.wrappers.scikit_learn.KerasRegressor(build_fn=create_model, verbose=0)
    print('Keras wrapper done')
    param = dict(epochs=epochs, batch_size=batch_size, neurons=neurons, H_layers=H_layers, learn_rate=learn_rate, weight_constraint=weight_constraint)
    #param = dict(neurons=neurons, H_layers=H_layers, learn_rate=learn_rate, weight_constraint=weight_constraint)
    
    if (search == 'random_search'):
        print('RANDOM SEARCH')
        grid = RandomizedSearchCV(estimator=model, param_distributions=param, n_iter=n_iter_search, n_jobs=1)
        print('Grid is prepared')
        start = time()
        grid.fit(X_train, Y_train)
        #grid.fit(X_train, Y_train, batch_size=500, epochs=1000)
        print("RandomizedSearchCV took %.2f seconds for %d candidates"
              " parameter settings." % ((time() - start), n_iter_search))
    else:
        print('GRIDSEARCH')
        grid = GridSearchCV(estimator=model, param_grid=param, n_jobs=1)
        print('Grid is prepared')
        start = time()
        grid.fit(X_train, Y_train)
        #grid.fit(X_train, Y_train, batch_size=500, epochs=1000)
        print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
              % (time() - start, len(grid.cv_results_['params'])))

    # summarize results (smallest loss?)
    print("Best: %f using %s" % (-grid.best_score_, grid.best_params_))
    means = grid.cv_results_['mean_test_score']
    stds = grid.cv_results_['std_test_score']
    params = grid.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (-mean, stdev, param))
    
    predictions = grid.best_estimator_.predict(X_test)
    
    print('\n')
    return (grid, predictions)

def run_ANN(X_train, Y_train, X_test):
    
    model = create_model(H_layers=H_layers, learn_rate=learn_rate, neurons=neurons, weight_constraint=weight_constraint)
    print('Keras wrapper done')
    model.compile(loss='mean_squared_error', optimizer='Adam', metrics=['mae'])
    model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, verbose=0)
        
    predictions = model.predict(X_test)
    
    print('\n')
    return (model, predictions)

def activation_function(x):
    return 1/(1+math.exp(-x))

### CHECK PROCEDURE ON TEST SET ###

def run_ANN_manually(X_val, X_val_scaled):
    #assuming biases are included
    b = 0
    k = 0
    #print('k', k)
    temp_saved = np.zeros([len(X_val_scaled), H_layers+1, neurons])
    predictions = np.zeros([len(X_val_scaled)])
    #print('temp_saved', temp_saved)
    while (H_layers-k)>=0:
        #print('while (H_layers-k)>=0:' ,H_layers-k)
        if (k==0):
            #print('k==0')
            for i in range(len(X_val_scaled)):
                #print('i', i)
                for j in range(neurons):
                    #print('j', j)
                    for l in range(N_nodes[t]):
                        #print('l', l)
                        temp_saved[i][k][j] += X_val_scaled[i][l]*weights[b][l][j]
                        #print('temp_saved', temp_saved)
                    temp_saved[i][k][j] += 1*weights[b+1][j]
                    #print('temp_saved', temp_saved)
                    temp_saved[i][k][j] = activation_function(temp_saved[i][k][j])
            #print('temp_saved', temp_saved)
            b += 2
            k += 1
        elif((H_layers-k)>0 and k!=0):
            #print('(H_layers-k)>0 and k!=0')
            #print('k', k)
            for i in range(len(X_val_scaled)):
                #print('i', i)
                for j in range(neurons):
                    #print('j', j)
                    for l in range(neurons):
                        #print('l', l)
                        temp_saved[i][k][j] += temp_saved[i][k-1][l]*weights[b][l][j]
                        #print('temp_saved', temp_saved)
                    temp_saved[i][k][j] += 1*weights[b+1][j]
                    #print('1*weights[k+2][j]', 1*weights[k+2][j])
                    #print('temp_saved', temp_saved)
                    temp_saved[i][k][j] = activation_function(temp_saved[i][k][j])
            #print('temp_saved', temp_saved)
            b += 2
            k += 1
        elif(H_layers-k)==0:
            #print('(H_layers-k)==0')
            #print('k', k)
            for i in range(len(X_val_scaled)):
                #print('i', i)
                for l in range(neurons):
                    #print('l', l)
                    temp_saved[i][k][0] += temp_saved[i][k-1][l]*weights[b][l][0]
                    predictions[i] += temp_saved[i][k-1][l]*weights[b][l][0]
                    #print('temp_saved', temp_saved)
                temp_saved[i][k][0] += 1*weights[b+1][0]
                predictions[i] += 1*weights[b+1][0]
                #print('temp_saved', temp_saved)
                temp_saved[i][k][0] = activation_function(temp_saved[i][k][0])
                predictions[i] = activation_function(predictions[i])
            #print('temp_saved', temp_saved)
            k += 1                                                     #stop while-loop

    plot_cdf(X_test, Y_test, X_val, Y_val, X_test_scaled, X_val_scaled, predictions)

    return (temp_saved, predictions)

def derivative_sigmoid(x):
    return 1/(1+math.exp(-x))*(1-1/(1+math.exp(-x)))

# %%
### K-FOLD SIMULATIONS ###

best_score = np.empty([n_split,])
dict_H_layers = np.empty([n_split,])
dict_learn_rate = np.empty([n_split,])
dict_neurons = np.empty([n_split,])
dict_weight_constraint = np.empty([n_split,])
dict_epochs = np.empty([n_split,])
dict_batch_size = np.empty([n_split,])
all_X_test_scaled = np.empty([n_split,int((observations+1-X_val_size-1)/n_split)])
all_predictions = np.empty([n_split,int((observations+1-X_val_size-1)/n_split)])

#create dataset
x_original = create_dataset()
index = np.random.choice(observations+1, X_val_size+1, replace=False)
    
X_val = x_original[index]
#Y_val = y[index]

x = np.delete(x_original, index, 0)
#y = np.delete(y, index, 0)

index_sort = np.argsort(X_val[:,0])
X_val = X_val[index_sort]
#Y_val = Y_val[index_sort]

#print('dimensionality of X_val: \t', np.shape(X_val))
#print('dimensionality of Y_val: \t', np.shape(Y_val))
#print('dimensionality of x : \t\t', np.shape(x))
#print('dimensionality of y: \t\t', np.shape(y), '\n')

kf = KFold(n_splits=n_split, shuffle=True, random_state=None)
kf.get_n_splits(x)
k = 1

print('Simulations')
M = 0
for train_index, test_index in kf.split(x):
    
    #y = np.sort(np.array([random.uniform(0,1) for i in range(0,observations+1)]))
    #y = np.array([0.95*i/observations+0.05 for i in range(0,observations+1)])
    y = create_targetset()
    plot_dataset(x_original, y)

    #take validation set out

    #X_val = x[0:(X_val_size+1)]
    #x = x[(X_val_size+1):(observations+1)]
    #Y_val = y[0:(X_val_size+1)]
    #y = y[(X_val_size+1):(observations+1)]

    #index = [random.randint(0,(observations+1)) for i in range(X_val_size+1)]
    index = np.random.choice(observations+1, X_val_size+1, replace=False)
    
    X_val = x_original[index]
    Y_val = y[index]

    x = np.delete(x_original, index, 0)
    y = np.delete(y, index, 0)

    index_sort = np.argsort(X_val[:,0])
    X_val = X_val[index_sort]
    Y_val = Y_val[index_sort]

    print('dimensionality of X_val: \t', np.shape(X_val))
    print('dimensionality of Y_val: \t', np.shape(Y_val))
    print('dimensionality of x : \t\t', np.shape(x))
    print('dimensionality of y: \t\t', np.shape(y), '\n')
    
    
    
    #create k-fold sets
    print(k, ':', 'TRAIN: ', len(train_index), 'TEST: ', len(test_index))
    #print('TRAIN: ', train_index, 'TEST: ', test_index)
    X_train, X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    print('X_train sample:', len(X_train), 'Y_train sample:', len(Y_train))
    print('first entry of sample X_test', X_test[0], 'first entry of sample Y_test', Y_test[0], '\n')

    print('X_train scaling:')
    X_train_scaled = scale(X_train)
    print('X_test scaling:')
    X_test_scaled = scale(X_test)

    MLP = create_model()
    print('MLP created')
    grid, predictions = train_ANN(search, X_train_scaled, Y_train, X_test_scaled)
    plot_cdf(X_train, Y_train, X_test, Y_test, X_train_scaled, X_test_scaled, predictions)
    ###

    best_score[M] = -grid.best_score_
    dict_H_layers[M] = grid.best_params_['H_layers']
    dict_learn_rate[M] = grid.best_params_['learn_rate']
    dict_neurons[M] = grid.best_params_['neurons']
    dict_weight_constraint[M] = grid.best_params_['weight_constraint']
    dict_epochs[M] = grid.best_params_['epochs']
    dict_batch_size[M] = grid.best_params_['batch_size']
    all_predictions[M] = predictions
    all_X_test_scaled[M] = X_test_scaled[:,0]
    
    k += 1
    M += 1
# Out:
# dimensionality of x : (600, 1)
#
#
# Simulations
# dimensionality of y:  (600,)
# dimensionality of X_val: 	 (100, 1)
# dimensionality of Y_val: 	 (100,)
# dimensionality of x : 		 (500, 1)
# dimensionality of y: 		 (500,)
#
# 1 : TRAIN:  400 TEST:  100
# X_train sample: 400 Y_train sample: 400
# first entry of sample X_test [ 0.00211215] first entry of sample Y_test 0.0030514142878
#
# X_train scaling:
# mean is:  [ 0.65370964]
# variance is:  [ 0.37879738]
#
#
# X_test scaling:
# mean is:  [ 0.6687556]
# variance is:  [ 0.71279053]
#
#
# MLP created
# Keras wrapper done
# RANDOM SEARCH
# Grid is prepared
# RandomizedSearchCV took 456.60 seconds for 10 candidates parameter settings.
# Best: 0.013720 using {'weight_constraint': 3, 'neurons': 20, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 50, 'H_layers': 5}
# 0.174369 (0.117060) with: {'weight_constraint': 0, 'neurons': 30, 'learn_rate': 0.1, 'epochs': 500, 'batch_size': 10, 'H_layers': 1}
# 0.176395 (0.118418) with: {'weight_constraint': 3, 'neurons': 10, 'learn_rate': 0.01, 'epochs': 100, 'batch_size': 10, 'H_layers': 10}
# 0.173762 (0.116592) with: {'weight_constraint': 0, 'neurons': 2, 'learn_rate': 0.1, 'epochs': 100, 'batch_size': 10, 'H_layers': 2}
# 0.169944 (0.114092) with: {'weight_constraint': 0, 'neurons': 1, 'learn_rate': 0.001, 'epochs': 100, 'batch_size': 50, 'H_layers': 2}
# 0.174287 (0.116978) with: {'weight_constraint': 0, 'neurons': 30, 'learn_rate': 0.01, 'epochs': 100, 'batch_size': 100, 'H_layers': 2}
# 0.173116 (0.116120) with: {'weight_constraint': 5, 'neurons': 1, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 100, 'H_layers': 5}
# 0.173686 (0.116534) with: {'weight_constraint': 0, 'neurons': 10, 'learn_rate': 0.01, 'epochs': 100, 'batch_size': 10, 'H_layers': 1}
# 0.013720 (0.010969) with: {'weight_constraint': 3, 'neurons': 20, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 50, 'H_layers': 5}
# 0.173831 (0.116641) with: {'weight_constraint': 0, 'neurons': 3, 'learn_rate': 0.01, 'epochs': 500, 'batch_size': 100, 'H_layers': 3}
# 0.174372 (0.117042) with: {'weight_constraint': 0, 'neurons': 20, 'learn_rate': 0.01, 'epochs': 50, 'batch_size': 25, 'H_layers': 3}
# dimensionality of y:  (600,)
# dimensionality of X_val: 	 (100, 1)
# dimensionality of Y_val: 	 (100,)
# dimensionality of x : 		 (500, 1)
# dimensionality of y: 		 (500,)
#
# 2 : TRAIN:  400 TEST:  100
# X_train sample: 400 Y_train sample: 400
# first entry of sample X_test [ 0.00211215] first entry of sample Y_test 0.000118458862988
#
# X_train scaling:
# mean is:  [ 0.68606513]
# variance is:  [ 0.47845897]
#
#
# X_test scaling:
# mean is:  [ 0.69755246]
# variance is:  [ 0.47404932]
#
#
# MLP created
# Keras wrapper done
# RANDOM SEARCH
# Grid is prepared
# RandomizedSearchCV took 482.11 seconds for 10 candidates parameter settings.
# Best: 0.008874 using {'weight_constraint': 3, 'neurons': 30, 'learn_rate': 0.3, 'epochs': 500, 'batch_size': 25, 'H_layers': 1}
# 0.170524 (0.114347) with: {'weight_constraint': 3, 'neurons': 10, 'learn_rate': 0.01, 'epochs': 50, 'batch_size': 100, 'H_layers': 10}
# 0.117855 (0.082033) with: {'weight_constraint': 3, 'neurons': 10, 'learn_rate': 0.3, 'epochs': 100, 'batch_size': 50, 'H_layers': 1}
# 0.161097 (0.108250) with: {'weight_constraint': 0, 'neurons': 4, 'learn_rate': 0.001, 'epochs': 50, 'batch_size': 25, 'H_layers': 1}
# 0.173550 (0.116435) with: {'weight_constraint': 0, 'neurons': 2, 'learn_rate': 0.01, 'epochs': 500, 'batch_size': 100, 'H_layers': 5}
# 0.172242 (0.115535) with: {'weight_constraint': 0, 'neurons': 20, 'learn_rate': 0.3, 'epochs': 50, 'batch_size': 25, 'H_layers': 5}
# 0.027057 (0.018806) with: {'weight_constraint': 3, 'neurons': 4, 'learn_rate': 0.2, 'epochs': 100, 'batch_size': 10, 'H_layers': 1}
# 0.134278 (0.089612) with: {'weight_constraint': 0, 'neurons': 1, 'learn_rate': 0.1, 'epochs': 50, 'batch_size': 50, 'H_layers': 10}
# 0.018354 (0.013228) with: {'weight_constraint': 3, 'neurons': 10, 'learn_rate': 0.2, 'epochs': 500, 'batch_size': 25, 'H_layers': 3}
# 0.008874 (0.005147) with: {'weight_constraint': 3, 'neurons': 30, 'learn_rate': 0.3, 'epochs': 500, 'batch_size': 25, 'H_layers': 1}
# 0.172652 (0.116176) with: {'weight_constraint': 3, 'neurons': 1, 'learn_rate': 0.2, 'epochs': 100, 'batch_size': 10, 'H_layers': 3}
# dimensionality of y:  (600,)
# dimensionality of X_val: 	 (100, 1)
# dimensionality of Y_val: 	 (100,)
# dimensionality of x : 		 (500, 1)
# dimensionality of y: 		 (500,)
#
# 3 : TRAIN:  400 TEST:  100
# X_train sample: 400 Y_train sample: 400
# first entry of sample X_test [ 0.00562367] first entry of sample Y_test 0.00287593465939
#
# X_train scaling:
# mean is:  [ 0.67486556]
# variance is:  [ 0.49280923]
#
#
# X_test scaling:
# mean is:  [ 0.69366166]
# variance is:  [ 0.43914908]
#
#
# MLP created
# Keras wrapper done
# RANDOM SEARCH
# Grid is prepared
# RandomizedSearchCV took 957.77 seconds for 10 candidates parameter settings.
# Best: 0.071682 using {'weight_constraint': 5, 'neurons': 1, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 10, 'H_layers': 5}
# 0.171771 (0.115283) with: {'weight_constraint': 5, 'neurons': 4, 'learn_rate': 0.01, 'epochs': 500, 'batch_size': 50, 'H_layers': 10}
# 0.138028 (0.095547) with: {'weight_constraint': 5, 'neurons': 5, 'learn_rate': 0.1, 'epochs': 50, 'batch_size': 100, 'H_layers': 10}
# 0.172118 (0.115568) with: {'weight_constraint': 5, 'neurons': 2, 'learn_rate': 0.001, 'epochs': 50, 'batch_size': 10, 'H_layers': 5}
# 0.118167 (0.077524) with: {'weight_constraint': 3, 'neurons': 1, 'learn_rate': 0.001, 'epochs': 50, 'batch_size': 100, 'H_layers': 2}
# 0.172940 (0.116085) with: {'weight_constraint': 5, 'neurons': 5, 'learn_rate': 0.3, 'epochs': 100, 'batch_size': 10, 'H_layers': 10}
# 0.150281 (0.102997) with: {'weight_constraint': 0, 'neurons': 10, 'learn_rate': 0.1, 'epochs': 50, 'batch_size': 100, 'H_layers': 5}
# 0.071682 (0.042585) with: {'weight_constraint': 5, 'neurons': 1, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 10, 'H_layers': 5}
# 0.155995 (0.104382) with: {'weight_constraint': 0, 'neurons': 5, 'learn_rate': 0.3, 'epochs': 100, 'batch_size': 100, 'H_layers': 3}
# 0.152169 (0.102465) with: {'weight_constraint': 5, 'neurons': 1, 'learn_rate': 0.001, 'epochs': 50, 'batch_size': 25, 'H_layers': 5}
# 0.088335 (0.057765) with: {'weight_constraint': 5, 'neurons': 10, 'learn_rate': 0.3, 'epochs': 50, 'batch_size': 25, 'H_layers': 1}
# dimensionality of y:  (600,)
# dimensionality of X_val: 	 (100, 1)
# dimensionality of Y_val: 	 (100,)
# dimensionality of x : 		 (500, 1)
# dimensionality of y: 		 (500,)
#
# 4 : TRAIN:  400 TEST:  100
# X_train sample: 400 Y_train sample: 400
# first entry of sample X_test [ 0.00976636] first entry of sample Y_test 0.00930980185749
#
# X_train scaling:
# mean is:  [ 0.67174791]
# variance is:  [ 0.48856108]
#
#
# X_test scaling:
# mean is:  [ 0.65542504]
# variance is:  [ 0.29503471]
#
#
# MLP created
# Keras wrapper done
# RANDOM SEARCH
# Grid is prepared
# RandomizedSearchCV took 684.49 seconds for 10 candidates parameter settings.
# Best: 0.012011 using {'weight_constraint': 5, 'neurons': 10, 'learn_rate': 0.01, 'epochs': 500, 'batch_size': 50, 'H_layers': 2}
# 0.181878 (0.120242) with: {'weight_constraint': 0, 'neurons': 2, 'learn_rate': 0.2, 'epochs': 500, 'batch_size': 50, 'H_layers': 1}
# 0.012011 (0.006452) with: {'weight_constraint': 5, 'neurons': 10, 'learn_rate': 0.01, 'epochs': 500, 'batch_size': 50, 'H_layers': 2}
# 0.170748 (0.115536) with: {'weight_constraint': 5, 'neurons': 5, 'learn_rate': 0.3, 'epochs': 100, 'batch_size': 25, 'H_layers': 3}
# 0.142692 (0.092647) with: {'weight_constraint': 0, 'neurons': 1, 'learn_rate': 0.01, 'epochs': 50, 'batch_size': 25, 'H_layers': 1}
# 0.014993 (0.008177) with: {'weight_constraint': 3, 'neurons': 10, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 50, 'H_layers': 2}
# 0.020215 (0.008536) with: {'weight_constraint': 5, 'neurons': 3, 'learn_rate': 0.01, 'epochs': 500, 'batch_size': 50, 'H_layers': 1}
# 0.068743 (0.033662) with: {'weight_constraint': 3, 'neurons': 3, 'learn_rate': 0.2, 'epochs': 500, 'batch_size': 50, 'H_layers': 3}
# 0.149573 (0.097507) with: {'weight_constraint': 3, 'neurons': 1, 'learn_rate': 0.3, 'epochs': 50, 'batch_size': 25, 'H_layers': 2}
# 0.182051 (0.120479) with: {'weight_constraint': 5, 'neurons': 10, 'learn_rate': 0.2, 'epochs': 50, 'batch_size': 50, 'H_layers': 5}
# 0.081703 (0.053009) with: {'weight_constraint': 5, 'neurons': 20, 'learn_rate': 0.3, 'epochs': 100, 'batch_size': 50, 'H_layers': 1}
# dimensionality of y:  (600,)
# dimensionality of X_val: 	 (100, 1)
# dimensionality of Y_val: 	 (100,)
# dimensionality of x : 		 (500, 1)
# dimensionality of y: 		 (500,)
#
# 5 : TRAIN:  400 TEST:  100
# X_train sample: 400 Y_train sample: 400
# first entry of sample X_test [ 0.00766096] first entry of sample Y_test 0.0146331602019
#
# X_train scaling:
# mean is:  [ 0.68854642]
# variance is:  [ 0.49505876]
#
#
# X_test scaling:
# mean is:  [ 0.66037416]
# variance is:  [ 0.40374505]
#
#
# MLP created
# Keras wrapper done
# RANDOM SEARCH
# Grid is prepared
# RandomizedSearchCV took 725.14 seconds for 10 candidates parameter settings.
# Best: 0.061674 using {'weight_constraint': 3, 'neurons': 20, 'learn_rate': 0.01, 'epochs': 50, 'batch_size': 25, 'H_layers': 2}
# 0.160423 (0.107400) with: {'weight_constraint': 5, 'neurons': 4, 'learn_rate': 0.1, 'epochs': 50, 'batch_size': 50, 'H_layers': 1}
# 0.179815 (0.120099) with: {'weight_constraint': 3, 'neurons': 1, 'learn_rate': 0.1, 'epochs': 500, 'batch_size': 25, 'H_layers': 10}
# 0.176945 (0.118314) with: {'weight_constraint': 0, 'neurons': 1, 'learn_rate': 0.001, 'epochs': 50, 'batch_size': 25, 'H_layers': 3}
# 0.111556 (0.071982) with: {'weight_constraint': 3, 'neurons': 2, 'learn_rate': 0.1, 'epochs': 50, 'batch_size': 100, 'H_layers': 1}
# 0.061674 (0.051332) with: {'weight_constraint': 3, 'neurons': 20, 'learn_rate': 0.01, 'epochs': 50, 'batch_size': 25, 'H_layers': 2}
# 0.141305 (0.092975) with: {'weight_constraint': 5, 'neurons': 4, 'learn_rate': 0.3, 'epochs': 50, 'batch_size': 100, 'H_layers': 2}
# 0.178593 (0.119324) with: {'weight_constraint': 5, 'neurons': 2, 'learn_rate': 0.01, 'epochs': 50, 'batch_size': 10, 'H_layers': 3}
# 0.109880 (0.078969) with: {'weight_constraint': 5, 'neurons': 20, 'learn_rate': 0.01, 'epochs': 100, 'batch_size': 100, 'H_layers': 1}
# 0.069836 (0.073212) with: {'weight_constraint': 3, 'neurons': 30, 'learn_rate': 0.1, 'epochs': 100, 'batch_size': 100, 'H_layers': 2}
# 0.133566 (0.090140) with: {'weight_constraint': 5, 'neurons': 10, 'learn_rate': 0.2, 'epochs': 50, 'batch_size': 10, 'H_layers': 5}

# %%
#choose structure for MLP
print("Best error score: ", np.amin(best_score), "\n")
print("Chosen structure: ", '{ weight_constraint: ',dict_weight_constraint[np.argmin(best_score)],', neurons: ', dict_neurons[np.argmin(best_score)], ', learn_rate', dict_learn_rate[np.argmin(best_score)], ', epochs: ', dict_epochs[np.argmin(best_score)], ', batch_size', dict_batch_size[np.argmin(best_score)], ', H_layers', dict_H_layers[np.argmin(best_score)],'}' )

# fix hyperparameters
weight_constraint = int(dict_weight_constraint[np.argmin(best_score)])
neurons = int(dict_neurons[np.argmin(best_score)])
learn_rate = dict_learn_rate[np.argmin(best_score)]
epochs = int(dict_epochs[np.argmin(best_score)])
batch_size = int(dict_batch_size[np.argmin(best_score)])
H_layers = int(dict_H_layers[np.argmin(best_score)])

#run on last test set ONLY (?)
model, predictions = run_ANN(X_train_scaled, Y_train, X_test_scaled)
plot_cdf(X_train, Y_train, X_test, Y_test, X_train_scaled, X_test_scaled, predictions)

#retrieve these weights
#(map weights MLP to validation set)
weights = model.get_weights()
print("length weights", len(weights))
for i in range(len(weights)):
    print("layers length: (weight + possible bias)", weights[i].size)

#print(model.get_weights())
#print(model.get_config())

### CHECK PROCEDURE ON TEST SET ###
temp_not_saved, Tpredictions = run_ANN_manually(X_test, X_test_scaled)
### WARNING (still small differences)
np.in1d(predictions,Tpredictions)
diff = predictions[:,0]-Tpredictions
print('differences between keras and self-constructed-procedure: \n', abs(diff))

### MAP TESTWEIGHTS ON VALSET ###
print('X_val scaling:')
X_val_scaled = scale(X_val)
temp_saved, predictions = run_ANN_manually(X_val, X_val_scaled)
# Out:
# Best error score:  0.00887353478523
#
# Chosen structure:  { weight_constraint:  3.0 , neurons:  30.0 , learn_rate 0.3 , epochs:  500.0 , batch_size 25.0 , H_layers 1.0 }
# Keras wrapper done
# length weights 4
# layers length: (weight + possible bias) 30
# layers length: (weight + possible bias) 30
# layers length: (weight + possible bias) 30
# layers length: (weight + possible bias) 1
# differences between keras and self-constructed-procedure:
#  [  1.61631937e-09   1.33828832e-08   1.52495709e-08   7.02296865e-09
#    1.32424123e-08   2.02849531e-08   2.19318760e-08   1.84472312e-08
#    9.88702079e-09   1.74243189e-09   6.75241647e-09   5.07173559e-09
#    5.06335085e-09   4.15986371e-08   4.67937027e-08   7.65669161e-09
#    1.81811709e-08   4.54481727e-09   5.81367346e-09   3.60298455e-09
#    2.39211700e-08   2.73663733e-09   5.99099603e-09   1.74487515e-08
#    1.20014971e-08   4.29878732e-08   4.00199959e-08   3.66227765e-09
#    8.40876335e-09   1.63039466e-08   1.49901888e-08   7.88181787e-09
#    5.46610107e-09   1.66071985e-08   2.32089157e-08   1.95703660e-08
#    5.34688466e-09   4.78008811e-08   3.64254721e-08   6.82419143e-09
#    8.53570958e-09   1.68411697e-08   2.06476604e-08   1.92956064e-08
#    1.61947490e-08   3.53207732e-08   1.40843156e-08   2.98739256e-08
#    2.01705709e-08   2.98480589e-08   7.42626882e-09   1.53475358e-08
#    3.45940474e-08   3.18863594e-08   1.72116794e-08   3.26670103e-08
#    1.70439173e-08   3.33745782e-08   4.75385221e-08   5.44985918e-08
#    6.70463665e-08   6.47213183e-08   2.20401692e-08   7.27766025e-09
#    3.61402435e-08   4.03527212e-10   1.78626529e-08   3.95928338e-08
#    1.09947328e-08   9.63002733e-09   3.33040989e-08   6.88930945e-08
#    3.76109388e-09   1.10609517e-08   8.76740514e-09   1.46334825e-08
#    1.40314530e-08   3.49475361e-08   4.93442073e-08   4.51772377e-08
#    3.69496239e-08   1.20577042e-08   2.37156489e-08   9.74268011e-09
#    5.11320977e-08   3.39670476e-08   3.62598180e-08   1.05954758e-08
#    4.48878379e-09   1.83208921e-08   4.95401952e-08   6.03506667e-09
#    1.32389565e-08   2.38787315e-08   1.16876813e-08   7.09574591e-08
#    6.62989756e-08   3.68836858e-08   2.96491123e-08   3.42096009e-08]
# X_val scaling:
# mean is:  [ 0.634968]
# variance is:  [ 0.37053514]

# %%
def derivative(): 
    #i = len(temp_saved[0])-1
    i = 0
    k = len(weights)-4
    print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #neurons last hidden layer
    #temp_first = np.zeros([len(predictions), neurons])
    #for obs in range(len(predictions)):
        #print('obs', obs)
    #    for j in range(neurons):
            #print('j', j)
    #        temp_first[obs][j] = weights[k][j][0]
    #print('temp_first', temp_first)
    #k -= 2
    #i -= 1
    #i += 1
    #print('temp_first (neurons last hidden layer)', temp_first[0], '\n')
    #print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #temp_layers (neurons middle layers)
    if H_layers > 1:
        print('STEP LAYERS')
        temp_layers = dict()
        qq = H_layers-1
        for q in range(0, (H_layers-1)):
            print('NEW LAYER')
            print('q', q)
            temp_layers[q] = np.zeros([len(predictions), neurons])
            for obs in range(len(predictions)):
                #print('NEW OBS')
                #print('obs', obs)
                for p in range(neurons):
                    #print('p', p)
                    if(q==0):
                        #print('IF')
                        for l in range(neurons):
                            #print('l', l)
                            temp_sum = 0
                            for m in range(neurons):
                                #print('m', m)
                                #print('weights[k][m][l]','weights[',k,'][',m,'][',l,']')
                                #print('temp_saved[obs][qq-1][m]','temp_saved[',obs,'][',qq-1,'][',m,']')
                                temp_sum += temp_saved[obs][qq-1][m]*weights[k][m][l]
                            #print('derivative_sigmoid(temp_sum+weights[k+1][p])','derivative_sigmoid(temp_sum+weights[',k+1,'][',l,'])')
                            #print('weights[k+2][l][0]','weights[',k+2,'][',l,'][',0,']')
                            #print('weights[k][p][l]','weights[',k,'][',p,'][',l,']')
                            temp_layers[q][obs][p] += weights[k+2][l][0]*derivative_sigmoid(temp_sum+weights[k+1][l])*weights[k][p][l]
                    else:
                        #print('ELSE')
                        for l in range(neurons):
                            #print('l', l)
                            temp_sum = 0
                            for m in range(neurons):
                                #print('m', m)
                                #print('weights[k][m][l]','weights[',k,'][',m,'][',l,']')
                                #print('temp_saved[obs][qq-1][m]','temp_saved[',obs,'][',qq-1,'][',m,']')
                                temp_sum += temp_saved[obs][qq-1][m]*weights[k][m][l]
                            #print('derivative_sigmoid(temp_sum+weights[k+1][l])','derivative_sigmoid(temp_sum+weights[',k+1,'][',l,'])')
                            #print('temp_layers[q-1][obs][l]','temp_layers[',q-1,'][',obs,'][',l,']')
                            #print('weights[k][p][l]','weights[',k,'][',p,'][',l,']')
                            temp_layers[q][obs][p] += temp_layers[q-1][obs][l]*derivative_sigmoid(temp_sum+weights[k+1][l])*weights[k][p][l]

            k -= 2
            i += 1
            qq -= 1

    print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #derivative input layer
    print('LAST STEP')
    temp_last = np.zeros([len(predictions), N_nodes[t]])
    for obs in range(len(predictions)):
        #print('NEW OBS')
        #print('obs', obs)
        for pp in range(N_nodes[t]):
            #print('pp', pp)
            for p in range(neurons):
                #print('p', p)
                if H_layers == 1:
                    #print('IF')
                    temp_sum = 0
                    for l in range(N_nodes[t]):
                        #print('l', l)
                        for m in range(N_nodes[t]):
                            #print('m', m)
                            #print('weights[0][m][p]', 'weights[0][',m,'][',p,']')
                            #print('X_val[obs][m]', 'X_val[',obs,'][',m,']')
                            temp_sum += weights[0][m][p]*X_val[obs][m]
                        #print('temp_sum+weights[k+1][p]', 'temp_sum+weights[',k+1,'][',p,']')
                        #print('weights[len(weights)-2][p][0]', 'weights[',len(weights)-2,'][',p,'][0]')
                        #print('weights[0][0][p]', 'weights[0][0][',p,']')

                        #temp_last[obs][pp] += temp_first[obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p]
                        #print('previous temp_last[obs][pp]', temp_last[obs][pp])
                        temp_last[obs][pp] += weights[len(weights)-2][p][0]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][l][p]
                        #print('temp_last[obs][pp]', 'temp_last[',obs,'][',pp,']', weights[len(weights)-2][p][0]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p])
                        #print('temp_last[obs]', temp_last[obs])
                    
                else:
                    #print('ELSE')
                    temp_sum = 0
                    for l in range(N_nodes[t]):
                        #print('l', l)
                        for m in range(N_nodes[t]):
                            #print('m', m)
                            #print('weights[0][m][p]', 'weights[0][',m,'][',p,']')
                            #print('X_val[obs][m]', 'X_val[',obs,'][',m,']')
                            temp_sum += weights[0][m][p]*X_val[obs][m]
                        #print('temp_sum+weights[k+1][p]', 'temp_sum+weights[',k+1,'][',p,']')
                        #print('temp_layers[(H_layers-2)][obs][p]', 'temp_layers[(',H_layers-2,')][',obs,'][',p,']')
                        #print('weights[0][0][p]', 'weights[0][0][',p,']')

                        #temp_last[obs][pp] += temp_layers[(H_layers-2)][obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p]
                        temp_last[obs][pp] += temp_layers[len(temp_layers.keys())-1][obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][l][p]

    return temp_last

# %%
### DERIVATIVE H=? ###
outcome = derivative()

for i in range(N_nodes[t]):
    #plt.scatter(X_val_scaled, temp_last[:,0], label="scaled fitted set")
    #plt.scatter(X_val_scaled, expon.pdf(X_test,scale=1/lambd), label="scaled actual PDF")
    plt.scatter(X_val[:,i], outcome[:,i], label="fitted set")
    plt.scatter(X_val[:,i], expon.pdf(X_test[:,i],scale=1/lambd), label="actual PDF")
    plt.legend()
    plt.show()

for i in range(N_nodes[t]):
    plt.scatter(X_val[:,i], outcome[:,i], label="fitted set")
    plt.legend()
    plt.show()
# Out:
# iterator temp_saved i:  0 iterator weights k:  0
# iterator temp_saved i:  0 iterator weights k:  0
# LAST STEP

# %%
def derivative_2(): 
    #i = len(temp_saved[0])-1
    i = 0
    k = len(weights)-4
    print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #neurons last hidden layer
    #temp_first = np.zeros([len(predictions), neurons])
    #for obs in range(len(predictions)):
        #print('obs', obs)
    #    for j in range(neurons):
            #print('j', j)
    #        temp_first[obs][j] = weights[k][j][0]
    #print('temp_first', temp_first)
    #k -= 2
    #i -= 1
    #i += 1
    #print('temp_first (neurons last hidden layer)', temp_first[0], '\n')
    #print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #temp_layers (neurons middle layers)
    if H_layers > 1:
        print('STEP LAYERS')
        temp_layers = dict()
        qq = H_layers-1
        for q in range(0, (H_layers-1)):
            print('NEW LAYER')
            print('q', q)
            temp_layers[q] = np.zeros([len(predictions), neurons])
            for obs in range(len(predictions)):
                #print('NEW OBS')
                #print('obs', obs)
                for p in range(neurons):
                    #print('p', p)
                    if(q==0):
                        #print('IF')
                        for l in range(neurons):
                            #print('l', l)
                            temp_sum = 0
                            for m in range(neurons):
                                #print('m', m)
                                #print('weights[k][m][l]','weights[',k,'][',m,'][',l,']')
                                #print('temp_saved[obs][qq-1][m]','temp_saved[',obs,'][',qq-1,'][',m,']')
                                temp_sum += temp_saved[obs][qq-1][m]*weights[k][m][l]
                            #print('derivative_sigmoid(temp_sum+weights[k+1][p])','derivative_sigmoid(temp_sum+weights[',k+1,'][',l,'])')
                            #print('weights[k+2][l][0]','weights[',k+2,'][',l,'][',0,']')
                            #print('weights[k][p][l]','weights[',k,'][',p,'][',l,']')
                            temp_layers[q][obs][p] += weights[k+2][l][0]*derivative_sigmoid(temp_sum+weights[k+1][l])*weights[k][p][l]
                    else:
                        #print('ELSE')
                        for l in range(neurons):
                            #print('l', l)
                            temp_sum = 0
                            for m in range(neurons):
                                #print('m', m)
                                #print('weights[k][m][l]','weights[',k,'][',m,'][',l,']')
                                #print('temp_saved[obs][qq-1][m]','temp_saved[',obs,'][',qq-1,'][',m,']')
                                temp_sum += temp_saved[obs][qq-1][m]*weights[k][m][l]
                            #print('derivative_sigmoid(temp_sum+weights[k+1][l])','derivative_sigmoid(temp_sum+weights[',k+1,'][',l,'])')
                            #print('temp_layers[q-1][obs][l]','temp_layers[',q-1,'][',obs,'][',l,']')
                            #print('weights[k][p][l]','weights[',k,'][',p,'][',l,']')
                            temp_layers[q][obs][p] += temp_layers[q-1][obs][l]*derivative_sigmoid(temp_sum+weights[k+1][l])*weights[k][p][l]

            k -= 2
            i += 1
            qq -= 1

    print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #derivative input layer
    print('LAST STEP')
    temp_last = np.zeros([len(predictions), N_nodes[t]])
    for obs in range(len(predictions)):
        #print('NEW OBS')
        #print('obs', obs)
        for pp in range(N_nodes[t]):
            #print('pp', pp)
            for p in range(neurons):
                #print('p', p)
                if H_layers == 1:
                    #print('IF')
                    temp_sum = 0
                    for m in range(N_nodes[t]):
                        #print('m', m)
                        #print('weights[0][m][p]', 'weights[0][',m,'][',p,']')
                        #print('X_val[obs][m]', 'X_val[',obs,'][',m,']')
                        temp_sum += weights[0][m][p]*X_val[obs][m]
                    #print('temp_sum+weights[k+1][p]', 'temp_sum+weights[',k+1,'][',p,']')
                    #print('weights[len(weights)-2][p][0]', 'weights[',len(weights)-2,'][',p,'][0]')
                    #print('weights[0][0][p]', 'weights[0][0][',p,']')

                    #temp_last[obs][pp] += temp_first[obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p]
                    #print('previous temp_last[obs][pp]', temp_last[obs][pp])
                    #print("len(weights)-2", len(weights)-2)
                    temp_last[obs][pp] += weights[len(weights)-2][p][0]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][pp][p]
                    #print('temp_last[obs][pp]', 'temp_last[',obs,'][',pp,']', weights[len(weights)-2][p][0]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p])
                    #print('temp_last[obs]', temp_last[obs])
                    
                else:
                    #print('ELSE')
                    temp_sum = 0
                    for m in range(N_nodes[t]):
                        #print('m', m)
                        #print('weights[0][m][p]', 'weights[0][',m,'][',p,']')
                        #print('X_val[obs][m]', 'X_val[',obs,'][',m,']')
                        temp_sum += weights[0][m][p]*X_val[obs][m]
                    #print('temp_sum+weights[k+1][p]', 'temp_sum+weights[',k+1,'][',p,']')
                    #print('temp_layers[(H_layers-2)][obs][p]', 'temp_layers[(',H_layers-2,')][',obs,'][',p,']')
                    #print('weights[0][0][p]', 'weights[0][0][',p,']')

                    #temp_last[obs][pp] += temp_layers[(H_layers-2)][obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p]
                    #print("len(temp_layers.keys())", len(temp_layers.keys()))
                    temp_last[obs][pp] += temp_layers[len(temp_layers.keys())-2][obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][pp][p]

    return temp_last

# %%
### DERIVATIVE H=? ###
outcome = derivative_2()

for i in range(N_nodes[t]):
    #plt.scatter(X_val_scaled, temp_last[:,0], label="scaled fitted set")
    #plt.scatter(X_val_scaled, expon.pdf(X_test,scale=1/lambd), label="scaled actual PDF")
    plt.scatter(X_val[:,i], outcome[:,i], label="fitted set")
    plt.scatter(X_val[:,i], expon.pdf(X_test[:,i],scale=1/lambd), label="actual PDF")
    plt.legend()
    plt.show()

for i in range(N_nodes[t]):
    plt.scatter(X_val[:,i], outcome[:,i], label="fitted set")
    plt.legend()
    plt.show()
# Out:
# iterator temp_saved i:  0 iterator weights k:  0
# iterator temp_saved i:  0 iterator weights k:  0
# LAST STEP

# %%
weights
