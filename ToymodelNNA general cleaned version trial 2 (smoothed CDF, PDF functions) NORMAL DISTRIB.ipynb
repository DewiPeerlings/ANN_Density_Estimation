# %%
#update compared to trial 1: target values uniformly distributed every trial again!

import copy
import numpy as np
import pandas as pd
import seaborn as sns
import os
import matplotlib.pyplot as plt
import time
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

import keras
from keras import initializers
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from keras.constraints import max_norm
from scipy.stats import pearsonr
from scipy.stats import norm

from time import time
import math

import random
from scipy.misc import comb
# Out:
# Using TensorFlow backend.

# %%
### TUNING PARAMETERS ###

observations = 599                    # Sample construction
X_val_size = 99
n_split = 5
                      
N_nodes = [1, 2, 3]                    # Design MLP                       
t=0
H_layers = [1, 2, 3, 5, 10]


m = 0                                  # Distribution parameters
sd = 1               
alpha = 0.5
beta = 0.5
lambd = 1.5
a = 0.25
b = 0.75

                                       # Grid search hyperparameters
batch_size = [10, 25, 50, 100]
epochs = [50, 100, 500]

dropout_rate = [i/5 for i in range(0,5)]
learn_rate = [0.001, 0.01, 0.1, 0.2, 0.3]
weight_constraint = [0, 3, 5]

neurons = [1, 2, 3, 4, 5, 10, 20, 30]

                                       #grid_search or random_search?
search = "random_search"
n_iter_search = 10

t_size = 0.4

# %%
### FUNCTIONS ###

def create_dataset():
    x = np.array([[random.gauss(m, sd) for i in range(N_nodes[t])] for i in range(0, observations+1)])
    #y = np.array([0.95*i/observations+0.05 for i in range(0,observations+1)])
    
    #check dimensionality
    print('dimensionality of x :', np.shape(x))
    #print('dimensionality of y: ', np.shape(y))
    
    #sort
    x_sorted = np.sort(x,0)

    #correlation
    #for i in range(N_nodes[t]):
    #    print("correlation for " +str(N_nodes[t])+ ": ",pearsonr(x_sorted[:,0], y))
    
    print('\n')
    #return (x_sorted, y)
    return x_sorted

def create_targetset():
    #x = np.array([[random.gauss(m, sd) for i in range(N_nodes[t])] for i in range(0, observations+1)])
    #y = np.array([0.95*i/observations+0.05 for i in range(0,observations+1)])
    y = np.sort(np.array([random.uniform(0,1) for i in range(0,observations+1)]))
    
    #check dimensionality
    #print('dimensionality of x :', np.shape(x))
    print('dimensionality of y: ', np.shape(y))
    
    #sort
    #x_sorted = np.sort(x,0)

    #correlation
    #for i in range(N_nodes[t]):
    #    print("correlation for " +str(N_nodes[t])+ ": ",pearsonr(x_sorted[:,0], y))
    
    print('\n')
    #return (x_sorted, y)
    return y

def scale(x):
    ### scale ###
    mean = np.mean(x, axis=0)
    var = np.var(x, axis=0)
    print("mean is: ", mean)
    print("variance is: ", var)

    x_scaled = np.array([(i-mean)/np.sqrt(var) for i in x])
    
    print('\n')
    return x_scaled


def plot_dataset(x, y):
    
    for i in range(N_nodes[t]):
        plt.scatter(x[:,i], y, c=y)
        plt.ylabel('Cumulative Probability < RV value')
        plt.xlabel('Random Variable (RV) value')
        plt.plot(x[:,i], norm.cdf(x[:,i]), label="actual CDF")
        plt.colorbar(ticks=np.linspace(min(y), max(y), 10, endpoint=True))
        plt.show()
    

def plot_cdf(X_train, Y_train, X_test, Y_test, X_train_scaled, X_test_scaled, predictions):
        for i in range(N_nodes[t]):
            plt.scatter(X_test[:,i], Y_test, label='test set')
            plt.scatter(X_test[:,i], predictions, label='fitted set')
            plt.scatter(X_test[:,i], norm.cdf(X_test[:,i]), label="actual CDF")

            plt.ylabel('Cumulative Probability < RV value')
            plt.xlabel('Random Variable (RV) value')
            plt.legend()
            plt.show()
        
def create_model(H_layers=1, optimizer='Adam', init=initializers.RandomNormal(mean=0, stddev=0.25, seed=None), activation='sigmoid', dropout_rate=0.0, learn_rate=0.01, neurons=1, weight_constraint=0):
#def create_model(optimizer, init, dropout_rate, learn_rate, activation, neurons, weight_constraint):
    ### CREATE MODEL ###
    MLP = Sequential()
    #MLP.add(Dropout(dropout_rate, input_shape=(N_nodes[t],)))
    MLP.add(Dense(neurons, input_dim=N_nodes[t], kernel_initializer=init, activation=activation, kernel_constraint=max_norm(weight_constraint)))    #hidden layer
    #MLP.add(Dropout(dropout_rate))
    for h in range(1,H_layers):                                                                     #multiple hidden layers
        MLP.add(Dense(neurons, kernel_initializer=init, activation=activation, kernel_constraint=max_norm(weight_constraint)))
        #MLP.add(Dropout(dropout_rate))
    MLP.add(Dense(1, kernel_initializer=init, activation='sigmoid'))                                 #output layer
    MLP.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mae'])
    
    return MLP

def train_ANN(search, X_train, Y_train, X_test):
    
    model = keras.wrappers.scikit_learn.KerasRegressor(build_fn=create_model, verbose=0)
    print('Keras wrapper done')
    param = dict(epochs=epochs, batch_size=batch_size, neurons=neurons, H_layers=H_layers, learn_rate=learn_rate, weight_constraint=weight_constraint)
    #param = dict(neurons=neurons, H_layers=H_layers, learn_rate=learn_rate, weight_constraint=weight_constraint)
    
    if (search == 'random_search'):
        print('RANDOM SEARCH')
        grid = RandomizedSearchCV(estimator=model, param_distributions=param, n_iter=n_iter_search, n_jobs=1)
        print('Grid is prepared')
        start = time()
        grid.fit(X_train, Y_train)
        #grid.fit(X_train, Y_train, batch_size=500, epochs=1000)
        print("RandomizedSearchCV took %.2f seconds for %d candidates"
              " parameter settings." % ((time() - start), n_iter_search))
    else:
        print('GRIDSEARCH')
        grid = GridSearchCV(estimator=model, param_grid=param, n_jobs=1)
        print('Grid is prepared')
        start = time()
        grid.fit(X_train, Y_train)
        #grid.fit(X_train, Y_train, batch_size=500, epochs=1000)
        print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
              % (time() - start, len(grid.cv_results_['params'])))

    # summarize results (smallest loss?)
    print("Best: %f using %s" % (-grid.best_score_, grid.best_params_))
    means = grid.cv_results_['mean_test_score']
    stds = grid.cv_results_['std_test_score']
    params = grid.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (-mean, stdev, param))
    
    predictions = grid.best_estimator_.predict(X_test)
    
    print('\n')
    return (grid, predictions)

def run_ANN(X_train, Y_train, X_test):
    
    model = create_model(H_layers=H_layers, learn_rate=learn_rate, neurons=neurons, weight_constraint=weight_constraint)
    print('Keras wrapper done')
    model.compile(loss='mean_squared_error', optimizer='Adam', metrics=['mae'])
    model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size, verbose=0)
        
    predictions = model.predict(X_test)
    
    print('\n')
    return (model, predictions)

def activation_function(x):
    return 1/(1+math.exp(-x))

### CHECK PROCEDURE ON TEST SET ###

def run_ANN_manually(X_val, X_val_scaled):
    #assuming biases are included
    b = 0
    k = 0
    #print('k', k)
    temp_saved = np.zeros([len(X_val_scaled), H_layers+1, neurons])
    predictions = np.zeros([len(X_val_scaled)])
    #print('temp_saved', temp_saved)
    while (H_layers-k)>=0:
        #print('while (H_layers-k)>=0:' ,H_layers-k)
        if (k==0):
            #print('k==0')
            for i in range(len(X_val_scaled)):
                #print('i', i)
                for j in range(neurons):
                    #print('j', j)
                    for l in range(N_nodes[t]):
                        #print('l', l)
                        temp_saved[i][k][j] += X_val_scaled[i][l]*weights[b][l][j]
                        #print('temp_saved', temp_saved)
                    temp_saved[i][k][j] += 1*weights[b+1][j]
                    #print('temp_saved', temp_saved)
                    temp_saved[i][k][j] = activation_function(temp_saved[i][k][j])
            #print('temp_saved', temp_saved)
            b += 2
            k += 1
        elif((H_layers-k)>0 and k!=0):
            #print('(H_layers-k)>0 and k!=0')
            #print('k', k)
            for i in range(len(X_val_scaled)):
                #print('i', i)
                for j in range(neurons):
                    #print('j', j)
                    for l in range(neurons):
                        #print('l', l)
                        temp_saved[i][k][j] += temp_saved[i][k-1][l]*weights[b][l][j]
                        #print('temp_saved', temp_saved)
                    temp_saved[i][k][j] += 1*weights[b+1][j]
                    #print('1*weights[k+2][j]', 1*weights[k+2][j])
                    #print('temp_saved', temp_saved)
                    temp_saved[i][k][j] = activation_function(temp_saved[i][k][j])
            #print('temp_saved', temp_saved)
            b += 2
            k += 1
        elif(H_layers-k)==0:
            #print('(H_layers-k)==0')
            #print('k', k)
            for i in range(len(X_val_scaled)):
                #print('i', i)
                for l in range(neurons):
                    #print('l', l)
                    temp_saved[i][k][0] += temp_saved[i][k-1][l]*weights[b][l][0]
                    predictions[i] += temp_saved[i][k-1][l]*weights[b][l][0]
                    #print('temp_saved', temp_saved)
                temp_saved[i][k][0] += 1*weights[b+1][0]
                predictions[i] += 1*weights[b+1][0]
                #print('temp_saved', temp_saved)
                temp_saved[i][k][0] = activation_function(temp_saved[i][k][0])
                predictions[i] = activation_function(predictions[i])
            #print('temp_saved', temp_saved)
            k += 1                                                     #stop while-loop

    plot_cdf(X_test, Y_test, X_val, Y_val, X_test_scaled, X_val_scaled, predictions)

    return (temp_saved, predictions)

def derivative_sigmoid(x):
    return 1/(1+math.exp(-x))*(1-1/(1+math.exp(-x)))

# %%
### K-FOLD SIMULATIONS ###

best_score = np.empty([n_split,])
dict_H_layers = np.empty([n_split,])
dict_learn_rate = np.empty([n_split,])
dict_neurons = np.empty([n_split,])
dict_weight_constraint = np.empty([n_split,])
dict_epochs = np.empty([n_split,])
dict_batch_size = np.empty([n_split,])
all_X_test_scaled = np.empty([n_split,int((observations+1-X_val_size-1)/n_split)])
all_predictions = np.empty([n_split,int((observations+1-X_val_size-1)/n_split)])

#create dataset
x_original = create_dataset()
index = np.random.choice(observations+1, X_val_size+1, replace=False)
    
X_val = x_original[index]
#Y_val = y[index]

x = np.delete(x_original, index, 0)
#y = np.delete(y, index, 0)

index_sort = np.argsort(X_val[:,0])
X_val = X_val[index_sort]
#Y_val = Y_val[index_sort]

#print('dimensionality of X_val: \t', np.shape(X_val))
#print('dimensionality of Y_val: \t', np.shape(Y_val))
#print('dimensionality of x : \t\t', np.shape(x))
#print('dimensionality of y: \t\t', np.shape(y), '\n')

kf = KFold(n_splits=n_split, shuffle=True, random_state=None)
kf.get_n_splits(x)
k = 1

print('Simulations')
M = 0
for train_index, test_index in kf.split(x):
    
    #y = np.sort(np.array([random.uniform(0,1) for i in range(0,observations+1)]))
    #y = np.array([0.95*i/observations+0.05 for i in range(0,observations+1)])
    y = create_targetset()
    plot_dataset(x_original, y)

    #take validation set out

    #X_val = x[0:(X_val_size+1)]
    #x = x[(X_val_size+1):(observations+1)]
    #Y_val = y[0:(X_val_size+1)]
    #y = y[(X_val_size+1):(observations+1)]

    #index = [random.randint(0,(observations+1)) for i in range(X_val_size+1)]
    index = np.random.choice(observations+1, X_val_size+1, replace=False)
    
    X_val = x_original[index]
    Y_val = y[index]

    x = np.delete(x_original, index, 0)
    y = np.delete(y, index, 0)

    index_sort = np.argsort(X_val[:,0])
    X_val = X_val[index_sort]
    Y_val = Y_val[index_sort]

    print('dimensionality of X_val: \t', np.shape(X_val))
    print('dimensionality of Y_val: \t', np.shape(Y_val))
    print('dimensionality of x : \t\t', np.shape(x))
    print('dimensionality of y: \t\t', np.shape(y), '\n')
    
    
    
    #create k-fold sets
    print(k, ':', 'TRAIN: ', len(train_index), 'TEST: ', len(test_index))
    #print('TRAIN: ', train_index, 'TEST: ', test_index)
    X_train, X_test = x[train_index], x[test_index]
    Y_train, Y_test = y[train_index], y[test_index]
    print('X_train sample:', len(X_train), 'Y_train sample:', len(Y_train))
    print('first entry of sample X_test', X_test[0], 'first entry of sample Y_test', Y_test[0], '\n')

    print('X_train scaling:')
    X_train_scaled = scale(X_train)
    print('X_test scaling:')
    X_test_scaled = scale(X_test)

    MLP = create_model()
    print('MLP created')
    grid, predictions = train_ANN(search, X_train_scaled, Y_train, X_test_scaled)
    plot_cdf(X_train, Y_train, X_test, Y_test, X_train_scaled, X_test_scaled, predictions)
    ###

    best_score[M] = -grid.best_score_
    dict_H_layers[M] = grid.best_params_['H_layers']
    dict_learn_rate[M] = grid.best_params_['learn_rate']
    dict_neurons[M] = grid.best_params_['neurons']
    dict_weight_constraint[M] = grid.best_params_['weight_constraint']
    dict_epochs[M] = grid.best_params_['epochs']
    dict_batch_size[M] = grid.best_params_['batch_size']
    all_predictions[M] = predictions
    all_X_test_scaled[M] = X_test_scaled[:,0]
    
    k += 1
    M += 1
# Out:
# dimensionality of x : (600, 1)
#
#
# Simulations
# dimensionality of y:  (600,)
# dimensionality of X_val: 	 (100, 1)
# dimensionality of Y_val: 	 (100,)
# dimensionality of x : 		 (500, 1)
# dimensionality of y: 		 (500,)
#
# 1 : TRAIN:  400 TEST:  100
# X_train sample: 400 Y_train sample: 400
# first entry of sample X_test [-2.40464797] first entry of sample Y_test 0.00515991275139
#
# X_train scaling:
# mean is:  [-0.035511]
# variance is:  [ 0.98978041]
#
#
# X_test scaling:
# mean is:  [ 0.16837369]
# variance is:  [ 1.02035734]
#
#
# MLP created
# Keras wrapper done
# RANDOM SEARCH
# Grid is prepared
# RandomizedSearchCV took 608.03 seconds for 10 candidates parameter settings.
# Best: 0.003153 using {'weight_constraint': 3, 'neurons': 20, 'learn_rate': 0.1, 'epochs': 500, 'batch_size': 10, 'H_layers': 2}
# 0.092717 (0.063500) with: {'weight_constraint': 5, 'neurons': 5, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 100, 'H_layers': 3}
# 0.097101 (0.065147) with: {'weight_constraint': 5, 'neurons': 1, 'learn_rate': 0.1, 'epochs': 50, 'batch_size': 100, 'H_layers': 3}
# 0.171420 (0.115065) with: {'weight_constraint': 0, 'neurons': 5, 'learn_rate': 0.3, 'epochs': 50, 'batch_size': 25, 'H_layers': 5}
# 0.172352 (0.115693) with: {'weight_constraint': 5, 'neurons': 1, 'learn_rate': 0.3, 'epochs': 500, 'batch_size': 10, 'H_layers': 10}
# 0.151074 (0.101153) with: {'weight_constraint': 3, 'neurons': 1, 'learn_rate': 0.2, 'epochs': 100, 'batch_size': 50, 'H_layers': 1}
# 0.003153 (0.002218) with: {'weight_constraint': 3, 'neurons': 20, 'learn_rate': 0.1, 'epochs': 500, 'batch_size': 10, 'H_layers': 2}
# 0.150269 (0.101086) with: {'weight_constraint': 5, 'neurons': 1, 'learn_rate': 0.01, 'epochs': 50, 'batch_size': 25, 'H_layers': 3}
# 0.171444 (0.115054) with: {'weight_constraint': 5, 'neurons': 10, 'learn_rate': 0.3, 'epochs': 100, 'batch_size': 100, 'H_layers': 10}
# 0.124067 (0.088564) with: {'weight_constraint': 3, 'neurons': 5, 'learn_rate': 0.01, 'epochs': 50, 'batch_size': 10, 'H_layers': 3}
# 0.171754 (0.115246) with: {'weight_constraint': 0, 'neurons': 20, 'learn_rate': 0.3, 'epochs': 100, 'batch_size': 50, 'H_layers': 5}
# dimensionality of y:  (600,)
# dimensionality of X_val: 	 (100, 1)
# dimensionality of Y_val: 	 (100,)
# dimensionality of x : 		 (500, 1)
# dimensionality of y: 		 (500,)
#
# 2 : TRAIN:  400 TEST:  100
# X_train sample: 400 Y_train sample: 400
# first entry of sample X_test [-2.40464797] first entry of sample Y_test 0.0102664500455
#
# X_train scaling:
# mean is:  [ 0.03874798]
# variance is:  [ 0.93702436]
#
#
# X_test scaling:
# mean is:  [-0.14386265]
# variance is:  [ 1.22726912]
#
#
# MLP created
# Keras wrapper done
# RANDOM SEARCH
# Grid is prepared
# RandomizedSearchCV took 1020.42 seconds for 10 candidates parameter settings.
# Best: 0.003882 using {'weight_constraint': 5, 'neurons': 20, 'learn_rate': 0.3, 'epochs': 500, 'batch_size': 100, 'H_layers': 2}
# 0.120167 (0.092823) with: {'weight_constraint': 5, 'neurons': 10, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 10, 'H_layers': 10}
# 0.098178 (0.062219) with: {'weight_constraint': 5, 'neurons': 5, 'learn_rate': 0.2, 'epochs': 50, 'batch_size': 100, 'H_layers': 1}
# 0.003882 (0.002569) with: {'weight_constraint': 5, 'neurons': 20, 'learn_rate': 0.3, 'epochs': 500, 'batch_size': 100, 'H_layers': 2}
# 0.128973 (0.085340) with: {'weight_constraint': 0, 'neurons': 3, 'learn_rate': 0.3, 'epochs': 50, 'batch_size': 50, 'H_layers': 1}
# 0.011322 (0.008640) with: {'weight_constraint': 5, 'neurons': 10, 'learn_rate': 0.01, 'epochs': 100, 'batch_size': 10, 'H_layers': 2}
# 0.016328 (0.011453) with: {'weight_constraint': 3, 'neurons': 3, 'learn_rate': 0.01, 'epochs': 500, 'batch_size': 10, 'H_layers': 5}
# 0.157100 (0.105649) with: {'weight_constraint': 5, 'neurons': 3, 'learn_rate': 0.01, 'epochs': 50, 'batch_size': 50, 'H_layers': 3}
# 0.160039 (0.107091) with: {'weight_constraint': 3, 'neurons': 3, 'learn_rate': 0.01, 'epochs': 50, 'batch_size': 25, 'H_layers': 10}
# 0.160388 (0.107337) with: {'weight_constraint': 0, 'neurons': 5, 'learn_rate': 0.3, 'epochs': 50, 'batch_size': 10, 'H_layers': 3}
# 0.008425 (0.005602) with: {'weight_constraint': 3, 'neurons': 30, 'learn_rate': 0.001, 'epochs': 100, 'batch_size': 25, 'H_layers': 3}
# dimensionality of y:  (600,)
# dimensionality of X_val: 	 (100, 1)
# dimensionality of Y_val: 	 (100,)
# dimensionality of x : 		 (500, 1)
# dimensionality of y: 		 (500,)
#
# 3 : TRAIN:  400 TEST:  100
# X_train sample: 400 Y_train sample: 400
# first entry of sample X_test [-3.03257541] first entry of sample Y_test 0.00470924871879
#
# X_train scaling:
# mean is:  [ 0.0028261]
# variance is:  [ 1.00081094]
#
#
# X_test scaling:
# mean is:  [ 0.02295184]
# variance is:  [ 0.95936436]
#
#
# MLP created
# Keras wrapper done
# RANDOM SEARCH
# Grid is prepared
# RandomizedSearchCV took 792.73 seconds for 10 candidates parameter settings.
# Best: 0.000837 using {'weight_constraint': 3, 'neurons': 30, 'learn_rate': 0.2, 'epochs': 100, 'batch_size': 10, 'H_layers': 1}
# 0.179378 (0.120078) with: {'weight_constraint': 0, 'neurons': 10, 'learn_rate': 0.3, 'epochs': 500, 'batch_size': 50, 'H_layers': 3}
# 0.002859 (0.003309) with: {'weight_constraint': 3, 'neurons': 20, 'learn_rate': 0.3, 'epochs': 500, 'batch_size': 100, 'H_layers': 1}
# 0.169930 (0.113068) with: {'weight_constraint': 5, 'neurons': 3, 'learn_rate': 0.2, 'epochs': 50, 'batch_size': 50, 'H_layers': 2}
# 0.179537 (0.120131) with: {'weight_constraint': 0, 'neurons': 2, 'learn_rate': 0.01, 'epochs': 500, 'batch_size': 25, 'H_layers': 2}
# 0.179603 (0.120218) with: {'weight_constraint': 3, 'neurons': 10, 'learn_rate': 0.001, 'epochs': 100, 'batch_size': 100, 'H_layers': 10}
# 0.172367 (0.114706) with: {'weight_constraint': 5, 'neurons': 1, 'learn_rate': 0.3, 'epochs': 100, 'batch_size': 25, 'H_layers': 5}
# 0.000837 (0.000391) with: {'weight_constraint': 3, 'neurons': 30, 'learn_rate': 0.2, 'epochs': 100, 'batch_size': 10, 'H_layers': 1}
# 0.018098 (0.021467) with: {'weight_constraint': 3, 'neurons': 10, 'learn_rate': 0.2, 'epochs': 100, 'batch_size': 25, 'H_layers': 1}
# 0.079685 (0.038659) with: {'weight_constraint': 5, 'neurons': 3, 'learn_rate': 0.2, 'epochs': 100, 'batch_size': 10, 'H_layers': 3}
# 0.012420 (0.013715) with: {'weight_constraint': 5, 'neurons': 4, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 25, 'H_layers': 1}
# dimensionality of y:  (600,)
# dimensionality of X_val: 	 (100, 1)
# dimensionality of Y_val: 	 (100,)
# dimensionality of x : 		 (500, 1)
# dimensionality of y: 		 (500,)
#
# 4 : TRAIN:  400 TEST:  100
# X_train sample: 400 Y_train sample: 400
# first entry of sample X_test [-2.32615283] first entry of sample Y_test 0.00677330883724
#
# X_train scaling:
# mean is:  [ 0.01454865]
# variance is:  [ 0.96163651]
#
#
# X_test scaling:
# mean is:  [ 0.0313248]
# variance is:  [ 0.9182146]
#
#
# MLP created
# Keras wrapper done
# RANDOM SEARCH
# Grid is prepared
# RandomizedSearchCV took 815.63 seconds for 10 candidates parameter settings.
# Best: 0.002165 using {'weight_constraint': 3, 'neurons': 30, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 100, 'H_layers': 1}
# 0.185959 (0.122921) with: {'weight_constraint': 5, 'neurons': 1, 'learn_rate': 0.2, 'epochs': 100, 'batch_size': 10, 'H_layers': 10}
# 0.002165 (0.001420) with: {'weight_constraint': 3, 'neurons': 30, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 100, 'H_layers': 1}
# 0.186398 (0.123280) with: {'weight_constraint': 0, 'neurons': 10, 'learn_rate': 0.2, 'epochs': 50, 'batch_size': 25, 'H_layers': 3}
# 0.124536 (0.085112) with: {'weight_constraint': 3, 'neurons': 20, 'learn_rate': 0.2, 'epochs': 50, 'batch_size': 50, 'H_layers': 2}
# 0.168360 (0.110617) with: {'weight_constraint': 0, 'neurons': 3, 'learn_rate': 0.2, 'epochs': 50, 'batch_size': 50, 'H_layers': 3}
# 0.186404 (0.123229) with: {'weight_constraint': 0, 'neurons': 4, 'learn_rate': 0.3, 'epochs': 50, 'batch_size': 10, 'H_layers': 10}
# 0.009886 (0.007303) with: {'weight_constraint': 3, 'neurons': 4, 'learn_rate': 0.2, 'epochs': 500, 'batch_size': 50, 'H_layers': 1}
# 0.185987 (0.122877) with: {'weight_constraint': 0, 'neurons': 30, 'learn_rate': 0.2, 'epochs': 50, 'batch_size': 25, 'H_layers': 2}
# 0.185892 (0.122917) with: {'weight_constraint': 0, 'neurons': 1, 'learn_rate': 0.2, 'epochs': 500, 'batch_size': 25, 'H_layers': 2}
# 0.186047 (0.123033) with: {'weight_constraint': 0, 'neurons': 30, 'learn_rate': 0.2, 'epochs': 50, 'batch_size': 100, 'H_layers': 1}
# dimensionality of y:  (600,)
# dimensionality of X_val: 	 (100, 1)
# dimensionality of Y_val: 	 (100,)
# dimensionality of x : 		 (500, 1)
# dimensionality of y: 		 (500,)
#
# 5 : TRAIN:  400 TEST:  100
# X_train sample: 400 Y_train sample: 400
# first entry of sample X_test [-1.84642894] first entry of sample Y_test 0.0306584275359
#
# X_train scaling:
# mean is:  [ 0.00917058]
# variance is:  [ 1.02903174]
#
#
# X_test scaling:
# mean is:  [-0.05152553]
# variance is:  [ 0.76315423]
#
#
# MLP created
# Keras wrapper done
# RANDOM SEARCH
# Grid is prepared
# RandomizedSearchCV took 1360.17 seconds for 10 candidates parameter settings.
# Best: 0.001715 using {'weight_constraint': 3, 'neurons': 20, 'learn_rate': 0.3, 'epochs': 50, 'batch_size': 10, 'H_layers': 1}
# 0.028817 (0.020026) with: {'weight_constraint': 3, 'neurons': 3, 'learn_rate': 0.3, 'epochs': 500, 'batch_size': 25, 'H_layers': 2}
# 0.183295 (0.123180) with: {'weight_constraint': 3, 'neurons': 10, 'learn_rate': 0.2, 'epochs': 50, 'batch_size': 25, 'H_layers': 10}
# 0.099129 (0.049161) with: {'weight_constraint': 3, 'neurons': 30, 'learn_rate': 0.2, 'epochs': 100, 'batch_size': 25, 'H_layers': 10}
# 0.123276 (0.084701) with: {'weight_constraint': 3, 'neurons': 2, 'learn_rate': 0.001, 'epochs': 100, 'batch_size': 100, 'H_layers': 1}
# 0.152350 (0.102673) with: {'weight_constraint': 5, 'neurons': 2, 'learn_rate': 0.2, 'epochs': 50, 'batch_size': 50, 'H_layers': 10}
# 0.001715 (0.001172) with: {'weight_constraint': 3, 'neurons': 20, 'learn_rate': 0.3, 'epochs': 50, 'batch_size': 10, 'H_layers': 1}
# 0.128820 (0.084441) with: {'weight_constraint': 3, 'neurons': 1, 'learn_rate': 0.001, 'epochs': 50, 'batch_size': 50, 'H_layers': 1}
# 0.014341 (0.010028) with: {'weight_constraint': 5, 'neurons': 4, 'learn_rate': 0.3, 'epochs': 500, 'batch_size': 10, 'H_layers': 5}
# 0.182811 (0.122554) with: {'weight_constraint': 0, 'neurons': 5, 'learn_rate': 0.001, 'epochs': 100, 'batch_size': 50, 'H_layers': 10}
# 0.098816 (0.067698) with: {'weight_constraint': 3, 'neurons': 2, 'learn_rate': 0.001, 'epochs': 500, 'batch_size': 50, 'H_layers': 3}

# %%
#choose structure for MLP
print("Best error score: ", np.amin(best_score), "\n")
print("Chosen structure: ", '{ weight_constraint: ',dict_weight_constraint[np.argmin(best_score)],', neurons: ', dict_neurons[np.argmin(best_score)], ', learn_rate', dict_learn_rate[np.argmin(best_score)], ', epochs: ', dict_epochs[np.argmin(best_score)], ', batch_size', dict_batch_size[np.argmin(best_score)], ', H_layers', dict_H_layers[np.argmin(best_score)],'}' )

# fix hyperparameters
weight_constraint = int(dict_weight_constraint[np.argmin(best_score)])
neurons = int(dict_neurons[np.argmin(best_score)])
learn_rate = dict_learn_rate[np.argmin(best_score)]
epochs = int(dict_epochs[np.argmin(best_score)])
batch_size = int(dict_batch_size[np.argmin(best_score)])
H_layers = int(dict_H_layers[np.argmin(best_score)])

#run on last test set ONLY (?)
model, predictions = run_ANN(X_train_scaled, Y_train, X_test_scaled)
plot_cdf(X_train, Y_train, X_test, Y_test, X_train_scaled, X_test_scaled, predictions)

#retrieve these weights
#(map weights MLP to validation set)
weights = model.get_weights()
print("length weights", len(weights))
for i in range(len(weights)):
    print("layers length: (weight + possible bias)", weights[i].size)

#print(model.get_weights())
#print(model.get_config())

### CHECK PROCEDURE ON TEST SET ###
temp_not_saved, Tpredictions = run_ANN_manually(X_test, X_test_scaled)
### WARNING (still small differences)
np.in1d(predictions,Tpredictions)
diff = predictions[:,0]-Tpredictions
print('differences between keras and self-constructed-procedure: \n', abs(diff))

### MAP TESTWEIGHTS ON VALSET ###
print('X_val scaling:')
X_val_scaled = scale(X_val)
temp_saved, predictions = run_ANN_manually(X_val, X_val_scaled)
# Out:
# Best error score:  0.000836618832484
#
# Chosen structure:  { weight_constraint:  3.0 , neurons:  30.0 , learn_rate 0.2 , epochs:  100.0 , batch_size 10.0 , H_layers 1.0 }
# Keras wrapper done
# length weights 4
# layers length: (weight + possible bias) 30
# layers length: (weight + possible bias) 30
# layers length: (weight + possible bias) 30
# layers length: (weight + possible bias) 1
# differences between keras and self-constructed-procedure:
#  [  1.82080354e-09   6.43440094e-09   1.52380595e-08   1.10819901e-08
#    1.36689658e-08   1.39092391e-08   7.59944502e-09   9.84075144e-09
#    3.02056771e-08   8.34144992e-09   2.25624167e-08   8.12643175e-10
#    2.81233424e-08   2.89671682e-08   3.01616346e-08   2.06592360e-09
#    2.57016682e-08   7.37924535e-09   8.19679372e-09   3.34850578e-08
#    1.15602175e-08   9.85651466e-09   4.54380999e-09   2.25186638e-08
#    2.73224043e-08   1.75589980e-08   5.54940918e-08   6.35212488e-09
#    1.73503139e-08   3.92950975e-08   1.35390817e-08   2.04768985e-08
#    1.23421760e-08   1.34015812e-08   6.08069379e-08   2.53664487e-08
#    1.63883668e-08   5.60937896e-09   2.42978394e-08   4.20608798e-09
#    1.22750214e-08   3.96248913e-08   5.08586023e-08   5.58050228e-08
#    1.24558269e-08   1.49456809e-08   2.58631662e-08   3.31698929e-09
#    2.82025453e-09   1.52620938e-09   2.13701707e-08   2.41535309e-08
#    1.47318796e-08   5.25575000e-08   3.00561986e-09   2.48136561e-08
#    1.06517422e-08   3.55447272e-09   1.95583135e-08   4.60254959e-08
#    1.97727367e-08   3.39839651e-08   1.40734516e-08   2.37207797e-08
#    1.93509686e-08   2.35218434e-08   4.51044450e-08   2.54656752e-08
#    1.56688859e-08   3.61104190e-08   2.38325069e-08   2.73997127e-08
#    3.21995673e-08   3.80627782e-08   1.04032564e-07   2.72215721e-08
#    2.12163553e-09   1.17646863e-08   4.31891422e-08   2.34705934e-08
#    2.34379125e-08   2.64313027e-09   3.97706016e-08   3.87520785e-08
#    3.01819189e-08   5.67519887e-09   9.00689190e-10   1.70386132e-08
#    1.04916716e-08   8.40465110e-08   6.78209450e-08   6.45146048e-10
#    1.15481948e-08   1.97408079e-08   2.39677116e-08   1.24816701e-09
#    5.24630127e-08   1.12344689e-08   7.41769363e-08   1.68836524e-08]
# X_val scaling:
# mean is:  [ 0.02095702]
# variance is:  [ 1.03871265]

# %%
def derivative(): 
    #i = len(temp_saved[0])-1
    i = 0
    k = len(weights)-4
    print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #neurons last hidden layer
    #temp_first = np.zeros([len(predictions), neurons])
    #for obs in range(len(predictions)):
        #print('obs', obs)
    #    for j in range(neurons):
            #print('j', j)
    #        temp_first[obs][j] = weights[k][j][0]
    #print('temp_first', temp_first)
    #k -= 2
    #i -= 1
    #i += 1
    #print('temp_first (neurons last hidden layer)', temp_first[0], '\n')
    #print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #temp_layers (neurons middle layers)
    if H_layers > 1:
        print('STEP LAYERS')
        temp_layers = dict()
        qq = H_layers-1
        for q in range(0, (H_layers-1)):
            print('NEW LAYER')
            print('q', q)
            temp_layers[q] = np.zeros([len(predictions), neurons])
            for obs in range(len(predictions)):
                #print('NEW OBS')
                #print('obs', obs)
                for p in range(neurons):
                    #print('p', p)
                    if(q==0):
                        #print('IF')
                        for l in range(neurons):
                            #print('l', l)
                            temp_sum = 0
                            for m in range(neurons):
                                #print('m', m)
                                #print('weights[k][m][l]','weights[',k,'][',m,'][',l,']')
                                #print('temp_saved[obs][qq-1][m]','temp_saved[',obs,'][',qq-1,'][',m,']')
                                temp_sum += temp_saved[obs][qq-1][m]*weights[k][m][l]
                            #print('derivative_sigmoid(temp_sum+weights[k+1][p])','derivative_sigmoid(temp_sum+weights[',k+1,'][',l,'])')
                            #print('weights[k+2][l][0]','weights[',k+2,'][',l,'][',0,']')
                            #print('weights[k][p][l]','weights[',k,'][',p,'][',l,']')
                            temp_layers[q][obs][p] += weights[k+2][l][0]*derivative_sigmoid(temp_sum+weights[k+1][l])*weights[k][p][l]
                    else:
                        #print('ELSE')
                        for l in range(neurons):
                            #print('l', l)
                            temp_sum = 0
                            for m in range(neurons):
                                #print('m', m)
                                #print('weights[k][m][l]','weights[',k,'][',m,'][',l,']')
                                #print('temp_saved[obs][qq-1][m]','temp_saved[',obs,'][',qq-1,'][',m,']')
                                temp_sum += temp_saved[obs][qq-1][m]*weights[k][m][l]
                            #print('derivative_sigmoid(temp_sum+weights[k+1][l])','derivative_sigmoid(temp_sum+weights[',k+1,'][',l,'])')
                            #print('temp_layers[q-1][obs][l]','temp_layers[',q-1,'][',obs,'][',l,']')
                            #print('weights[k][p][l]','weights[',k,'][',p,'][',l,']')
                            temp_layers[q][obs][p] += temp_layers[q-1][obs][l]*derivative_sigmoid(temp_sum+weights[k+1][l])*weights[k][p][l]

            k -= 2
            i += 1
            qq -= 1

    print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #derivative input layer
    print('LAST STEP')
    temp_last = np.zeros([len(predictions), N_nodes[t]])
    for obs in range(len(predictions)):
        #print('NEW OBS')
        #print('obs', obs)
        for pp in range(N_nodes[t]):
            #print('pp', pp)
            for p in range(neurons):
                #print('p', p)
                if H_layers == 1:
                    #print('IF')
                    temp_sum = 0
                    for l in range(N_nodes[t]):
                        #print('l', l)
                        for m in range(N_nodes[t]):
                            #print('m', m)
                            #print('weights[0][m][p]', 'weights[0][',m,'][',p,']')
                            #print('X_val[obs][m]', 'X_val[',obs,'][',m,']')
                            temp_sum += weights[0][m][p]*X_val[obs][m]
                        #print('temp_sum+weights[k+1][p]', 'temp_sum+weights[',k+1,'][',p,']')
                        #print('weights[len(weights)-2][p][0]', 'weights[',len(weights)-2,'][',p,'][0]')
                        #print('weights[0][0][p]', 'weights[0][0][',p,']')

                        #temp_last[obs][pp] += temp_first[obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p]
                        #print('previous temp_last[obs][pp]', temp_last[obs][pp])
                        temp_last[obs][pp] += weights[len(weights)-2][p][0]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][l][p]
                        #print('temp_last[obs][pp]', 'temp_last[',obs,'][',pp,']', weights[len(weights)-2][p][0]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p])
                        #print('temp_last[obs]', temp_last[obs])
                    
                else:
                    #print('ELSE')
                    temp_sum = 0
                    for l in range(N_nodes[t]):
                        #print('l', l)
                        for m in range(N_nodes[t]):
                            #print('m', m)
                            #print('weights[0][m][p]', 'weights[0][',m,'][',p,']')
                            #print('X_val[obs][m]', 'X_val[',obs,'][',m,']')
                            temp_sum += weights[0][m][p]*X_val[obs][m]
                        #print('temp_sum+weights[k+1][p]', 'temp_sum+weights[',k+1,'][',p,']')
                        #print('temp_layers[(H_layers-2)][obs][p]', 'temp_layers[(',H_layers-2,')][',obs,'][',p,']')
                        #print('weights[0][0][p]', 'weights[0][0][',p,']')

                        #temp_last[obs][pp] += temp_layers[(H_layers-2)][obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p]
                        temp_last[obs][pp] += temp_layers[len(temp_layers.keys())-1][obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][l][p]

    return temp_last

# %%
### DERIVATIVE H=? ###
outcome = derivative()

for i in range(N_nodes[t]):
    #plt.scatter(X_val_scaled, temp_last[:,0], label="scaled fitted set")
    #plt.scatter(X_val_scaled, norm.pdf(X_test), label="scaled actual PDF")
    plt.scatter(X_val[:,i], outcome[:,i], label="fitted set")
    plt.scatter(X_val[:,i], norm.pdf(X_test[:,i]), label="actual PDF")
    plt.legend()
    plt.show()

for i in range(N_nodes[t]):
    plt.scatter(X_val[:,i], outcome[:,i], label="fitted set")
    plt.legend()
    plt.show()
# Out:
# iterator temp_saved i:  0 iterator weights k:  0
# iterator temp_saved i:  0 iterator weights k:  0
# LAST STEP

# %%
def derivative_2(): 
    #i = len(temp_saved[0])-1
    i = 0
    k = len(weights)-4
    print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #neurons last hidden layer
    #temp_first = np.zeros([len(predictions), neurons])
    #for obs in range(len(predictions)):
        #print('obs', obs)
    #    for j in range(neurons):
            #print('j', j)
    #        temp_first[obs][j] = weights[k][j][0]
    #print('temp_first', temp_first)
    #k -= 2
    #i -= 1
    #i += 1
    #print('temp_first (neurons last hidden layer)', temp_first[0], '\n')
    #print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #temp_layers (neurons middle layers)
    if H_layers > 1:
        print('STEP LAYERS')
        temp_layers = dict()
        qq = H_layers-1
        for q in range(0, (H_layers-1)):
            print('NEW LAYER')
            print('q', q)
            temp_layers[q] = np.zeros([len(predictions), neurons])
            for obs in range(len(predictions)):
                #print('NEW OBS')
                #print('obs', obs)
                for p in range(neurons):
                    #print('p', p)
                    if(q==0):
                        #print('IF')
                        for l in range(neurons):
                            #print('l', l)
                            temp_sum = 0
                            for m in range(neurons):
                                #print('m', m)
                                #print('weights[k][m][l]','weights[',k,'][',m,'][',l,']')
                                #print('temp_saved[obs][qq-1][m]','temp_saved[',obs,'][',qq-1,'][',m,']')
                                temp_sum += temp_saved[obs][qq-1][m]*weights[k][m][l]
                            #print('derivative_sigmoid(temp_sum+weights[k+1][p])','derivative_sigmoid(temp_sum+weights[',k+1,'][',l,'])')
                            #print('weights[k+2][l][0]','weights[',k+2,'][',l,'][',0,']')
                            #print('weights[k][p][l]','weights[',k,'][',p,'][',l,']')
                            temp_layers[q][obs][p] += weights[k+2][l][0]*derivative_sigmoid(temp_sum+weights[k+1][l])*weights[k][p][l]
                    else:
                        #print('ELSE')
                        for l in range(neurons):
                            #print('l', l)
                            temp_sum = 0
                            for m in range(neurons):
                                #print('m', m)
                                #print('weights[k][m][l]','weights[',k,'][',m,'][',l,']')
                                #print('temp_saved[obs][qq-1][m]','temp_saved[',obs,'][',qq-1,'][',m,']')
                                temp_sum += temp_saved[obs][qq-1][m]*weights[k][m][l]
                            #print('derivative_sigmoid(temp_sum+weights[k+1][l])','derivative_sigmoid(temp_sum+weights[',k+1,'][',l,'])')
                            #print('temp_layers[q-1][obs][l]','temp_layers[',q-1,'][',obs,'][',l,']')
                            #print('weights[k][p][l]','weights[',k,'][',p,'][',l,']')
                            temp_layers[q][obs][p] += temp_layers[q-1][obs][l]*derivative_sigmoid(temp_sum+weights[k+1][l])*weights[k][p][l]

            k -= 2
            i += 1
            qq -= 1

    print('iterator temp_saved i: ', i, 'iterator weights k: ', k)

    #derivative input layer
    print('LAST STEP')
    temp_last = np.zeros([len(predictions), N_nodes[t]])
    for obs in range(len(predictions)):
        #print('NEW OBS')
        #print('obs', obs)
        for pp in range(N_nodes[t]):
            #print('pp', pp)
            for p in range(neurons):
                #print('p', p)
                if H_layers == 1:
                    #print('IF')
                    temp_sum = 0
                    for m in range(N_nodes[t]):
                        #print('m', m)
                        #print('weights[0][m][p]', 'weights[0][',m,'][',p,']')
                        #print('X_val[obs][m]', 'X_val[',obs,'][',m,']')
                        temp_sum += weights[0][m][p]*X_val[obs][m]
                    #print('temp_sum+weights[k+1][p]', 'temp_sum+weights[',k+1,'][',p,']')
                    #print('weights[len(weights)-2][p][0]', 'weights[',len(weights)-2,'][',p,'][0]')
                    #print('weights[0][0][p]', 'weights[0][0][',p,']')

                    #temp_last[obs][pp] += temp_first[obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p]
                    #print('previous temp_last[obs][pp]', temp_last[obs][pp])
                    #print("len(weights)-2", len(weights)-2)
                    temp_last[obs][pp] += weights[len(weights)-2][p][0]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][pp][p]
                    #print('temp_last[obs][pp]', 'temp_last[',obs,'][',pp,']', weights[len(weights)-2][p][0]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p])
                    #print('temp_last[obs]', temp_last[obs])
                    
                else:
                    #print('ELSE')
                    temp_sum = 0
                    for m in range(N_nodes[t]):
                        #print('m', m)
                        #print('weights[0][m][p]', 'weights[0][',m,'][',p,']')
                        #print('X_val[obs][m]', 'X_val[',obs,'][',m,']')
                        temp_sum += weights[0][m][p]*X_val[obs][m]
                    #print('temp_sum+weights[k+1][p]', 'temp_sum+weights[',k+1,'][',p,']')
                    #print('temp_layers[(H_layers-2)][obs][p]', 'temp_layers[(',H_layers-2,')][',obs,'][',p,']')
                    #print('weights[0][0][p]', 'weights[0][0][',p,']')

                    #temp_last[obs][pp] += temp_layers[(H_layers-2)][obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][0][p]
                    #print("len(temp_layers.keys())", len(temp_layers.keys()))
                    temp_last[obs][pp] += temp_layers[len(temp_layers.keys())-2][obs][p]*derivative_sigmoid(temp_sum+weights[k+1][p])*weights[0][pp][p]

    return temp_last

# %%
### DERIVATIVE H=? ###
outcome = derivative_2()

for i in range(N_nodes[t]):
    #plt.scatter(X_val_scaled, temp_last[:,0], label="scaled fitted set")
    #plt.scatter(X_val_scaled, norm.pdf(X_test), label="scaled actual PDF")
    plt.scatter(X_val[:,i], outcome[:,i], label="fitted set")
    plt.scatter(X_val[:,i], norm.pdf(X_test[:,i]), label="actual PDF")
    plt.legend()
    plt.show()

for i in range(N_nodes[t]):
    plt.scatter(X_val[:,i], outcome[:,i], label="fitted set")
    plt.legend()
    plt.show()
# Out:
# iterator temp_saved i:  0 iterator weights k:  0
# iterator temp_saved i:  0 iterator weights k:  0
# LAST STEP

# %%
weights
